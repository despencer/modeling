# %%
# %matplotlib notebook
import matplotlib.pyplot as plt

# %%
import pandas as pd
import onedquad as quad

# %%
mod = quad.createball()
mod.setparam('ground.e',1)
mod.setparam('frame.v',10)

# %%
mod.getallparams()
# Out:
# {'frame': {'x': 20.0, 'v': 10, 'm': 1.0}, 'ground': {'e': 1}}

# %%
sym = pd.DataFrame(mod.simulate(0.0,40.0,0.0001))

# %%
sym
# Out:
#               t     framex     framev
# 0        0.0000  20.000000  10.000000
# 1        0.0001  20.001000   9.999020
# 2        0.0002  20.002000   9.998040
# 3        0.0003  20.003000   9.997060
# 4        0.0004  20.003999   9.996080
# ...         ...        ...        ...
# 399995  39.9995 -28.108470  15.941776
# 399996  39.9996 -28.106875  15.943607
# 399997  39.9997 -28.105281  15.945438
# 399998  39.9998 -28.103687  15.947268
# 399999  39.9999 -28.102092  15.949099
#
# [400000 rows x 3 columns]

# %%
plt.plot(sym[['t']],sym[['framex']])
# Out:
# <img src="data:image/png;base64,..." width="640">
