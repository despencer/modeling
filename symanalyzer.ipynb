# %%
# %matplotlib notebook
import matplotlib.pyplot as plt

# %%
import pandas as pd
import onedquad as quad

# %%
mod = quad.createball()

# %%
sym = pd.DataFrame(mod.simulate(0.0,20.0,0.0001))

# %%
sym
# Out:
#               t     framex     framev
# 0        0.0000  20.000000   0.000000
# 1        0.0001  20.000000  -0.000980
# 2        0.0002  20.000000  -0.001960
# 3        0.0003  20.000000  -0.002940
# 4        0.0004  19.999999  -0.003920
# ...         ...        ...        ...
# 199996  19.9996   2.493454  18.700914
# 199997  19.9997   2.495324  18.699934
# 199998  19.9998   2.497194  18.698954
# 199999  19.9999   2.499063  18.697974
# 200000  20.0000   2.500933  18.696994
#
# [200001 rows x 3 columns]

# %%
plt.plot(sym[['framex']])
# Out:
# <img src="data:image/png;base64,..." width="640">
